# %%
# # write text file only in jupyter
# %%writefile test.txt
# Hello this is a text file
# this is a second line
# this is the third line

# %%
myfile=open('test.txt')

# %%
pwd
# Out:
# 'c:\\Users\\saxen\\OneDrive\\Documents\\AIML\\Python\\AIML\\day_1'

# %%
myfile.read()
# Out:
# 'hello this is a text file\nthis is a second line\nthis is the third line'

# %%
myfile.read()
# Out:
# ''

# %%
# need to reset the cursor
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'hello this is a text file\nthis is a second line\nthis is the third line'

# %%
content=myfile.read() #everything as string

# %%
content
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines() #as a list
# Out:
# ['hello this is a text file\n',
#  'this is a second line\n',
#  'this is the third line']

# %%
myfile.close()

# %%
with open('test.txt') as my_new_file:
    contents=my_new_file.read()

# %%
contents
# Out:
# 'hello this is a text file\nthis is a second line\nthis is the third line'

# %%
#'r': read only
# 'w' : write only
# 'a' : append only
# 'r+' : reading and writing
# 'w+' : writing and reading (overwrites existing files or creates a new file)
with open('test.txt','a') as f:
    f.write("teesha")

# %%
with open('test1.txt','w') as f:
    f.write("teesha") ##overwrite or create new
