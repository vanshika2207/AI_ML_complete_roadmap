# %% [markdown]
# - Integers : int (eg-3,300,200) whole numbers
# - Floating Point : float (4.5)  number with decimal points
# - Strings : str ("teesha") ordered sequence of characters
# - Lists : list ([3,4,5]) ordered sequence of objects
# - Dictionaries : dict ({"my_key":"value","name":"test"}) undordered key : value pairs
# - Tuples : tup ((12,"abc")) ordered immutable sequence of objects
# - Sets : set ({"a","b"}) unordered collection of unique objects
# - Booleans : bool (True or False) Logical Value

# %% [markdown]
# # Numbers
# - Integers
# - Floating Points

# %%
2+1
# Out:
# 3

# %%
2*2
# Out:
# 4

# %%
3/2
# Out:
# 1.5

# %%
7/4
# Out:
# 1.75

# %%
7%4
# Out:
# 3

# %%
50%5
# Out:
# 0

# %%
2 ** 3
# Out:
# 8

# %%
2+10 * 10+3
# Out:
# 105

# %%
(2+10)*(10+3)
# Out:
# 156

# %% [markdown]
# ## Variable Assignments

# %% [markdown]
# ### Rules
# 1. Names cannot start with a number.
# 2. There can be no space in the name , use _instead
# 3. Can't use any of the special symbols
#
# ### Best Practices
# 1. pep8 convention to use lower case names
# 2. don't use reserve words as special names
#
# ### Dynamic Typing
# - Python uses dynamic typing which means we cannot reassign variables to different datatypes.
# - This means python very flexible in assigning datatypes and different from statically - typed
#
# ##### Pros of Dynamic typing
# - very fast to work with
# - aster development time
#
# ##### Cons of Dynamic typing
# - may result in bugs for unexpected data types
# - need to be aware of type()

# %%
## create a variable
a=8

# %%
# reassign a variable
a=10

# %%
a
# Out:
# 10

# %%
a=a+10

# %%
a
# Out:
# 20

# %%
## to find type
type(a)
# Out:
# int

# %%
a=56.8
print(type(a))
# Out:
# <class 'float'>

# %%
my_income=100
tax_rate=0.1
my_taxes=my_income*tax_rate

# %%
my_taxes
# Out:
# 10.0

# %% [markdown]
# ## Strings
#
# Strings are sequences of characters, using the syntax of either single quotes or double quotes :
# 'hello' "Hello" "I don't do that"
#
# - Strings are ordered sequences it mean we can using indexing and slicing to grab sub-sections of the string.
#
# - Indexing notation uses [] notation after the string (or variable assigned the string).
#
# - Indexing allows you to grab a single character from the string.
#
# - Indexing start at 0
#
# - Reverse string start at -1
#
# - slicing - allows to grab multiple characters  a slice of the string
#
# - [ start : stop : step ]

# %%
'hello'
# Out:
# 'hello'

# %%
"World"
# Out:
# 'World'

# %%
"I 'm going on the run"
# Out:
# "I 'm going on the run"

# %%
print('hello')
# Out:
# hello

# %%
'hello 1'
'hello 2'
# only print the last result
# Out:
# 'hello 2'

# %%
# therefore we use print statement
# \n - new line
# \t - tab
print('hello \nworld')
# Out:
# hello
# world

# %%
len('ss')
# Out:
# 2

# %%
len(' I am human')
# Out:
# 11

# %%
## Indexing
mystring="Hello World"

# %%
print(mystring)
# Out:
# Hello World

# %%
# first character
print(mystring[0])
# other character with help of index
print(mystring[9])
# Out:
# H
# l

# %%
# reverse string
print(mystring[-1])
print(mystring[-2])
# Out:
# d
# l

# %%
# slicing
mystring='abcdefghijk'
print(mystring[:])
# Out:
# abcdefghijk

# %%
print(mystring[2:])
# Out:
# cdefghijk

# %%
print(mystring[:4])
# Out:
# abcd

# %%
print(mystring[3:6])
# Out:
# def

# %%
print(mystring[::])
# Out:
# abcdefghijk

# %%
print(mystring[::2])
# Out:
# acegik

# %%
print(mystring[2:7:2])
# Out:
# ceg

# %%
print(mystring[::-1])
# Out:
# kjihgfedcba

# %% [markdown]
# ### String formatting
# - .format()
# - .fstring()
#
# - 'String here {} then also {} '.format('something1','something2')

# %%
print('This is a string {} '.format('Inserted'))
# Out:
# Tjis is a string Inserted

# %%
print('The {} {} {} '.format('fox','brown','quick'))
# Out:
# The fox brown quick

# %%
print('The {2} {1} {0} '.format('fox','brown','quick'))
# Out:
# The quick brown fox

# %%
print('The {0} {0} {0} '.format('fox','brown','quick'))
# Out:
# The fox fox fox

# %%
print('The {q} {b} {f} '.format(f='fox',b='brown',q='quick'))
# Out:
# The quick brown fox

# %%
print('The {f} {f} {f} '.format(f='fox',b='brown',q='quick'))
# Out:
# The fox fox fox

# %% [markdown]
# Float formatting follows "{value:width.precision f}"

# %%
result=100/777
result
# Out:
# 0.1287001287001287

# %%
print("The result was {}".format(result))
# Out:
# The result was 0.1287001287001287

# %%
print("The result was {r:1.3}".format(r=result))
# Out:
# The result was 0.129

# %%
print("The result was {r:10.3}".format(r=result))
# Out:
# The result was      0.129

# %%
result=105.6789
print("The result was {r:1.3}".format(r=result))
# Out:
# The result was 1.06e+02

# %% [markdown]
# f-string : python 3.6 introduced

# %%
name="Ben"
print(f"Hello {name}")
# Out:
# Hello Ben

# %%
age=56
print(f'{name} , age ={age}')
# Out:
# Ben , age =56

# %% [markdown]
# String Properties and Methods

# %%
## Immutability
name='TRAi'
# name[0]='d'

# %%
last_letters=name[1:]
'P'+last_letters
# Out:
# 'PRAi'

# %%
x='Hello world'

# %%
x+ " it is beautiful outside!"
# Out:
# 'Hello world it is beautiful outside!'

# %%
x*3
# Out:
# 'Hello worldHello worldHello world'

# %%
2+3
# Out:
# 5

# %%
'2'+'3'
# Out:
# '23'

# %%
x='Hello worls'

# %%
x.capitalize() #not in place methods
# Out:
# 'Hello worls'

# %%
x.casefold()
# Out:
# 'hello worls'

# %%
x.upper()
# Out:
# 'HELLO WORLS'

# %%
x.lower()
# Out:
# 'hello worls'

# %%
x.split() # by default the white space
# Out:
# ['Hello', 'worls']

# %%
x.split('o')
# Out:
# ['Hell', ' w', 'rls']

# %% [markdown]
# - Lists are ordered sequences that can hold a variety of object types.
# - They use [] brackets and commas to seprate objects in the list eg-[1,2,3,4,5]
# - List support indexing and slicing . List can be nested and also have a variety of useful methods that can be called off of them

# %%
my_lists=[1,3,6]

# %%
my_lists=['string',100,34.7]
print(len(my_lists))
# Out:
# 3

# %%
mylist=['one','two','three']

# %%
mylist[0]
# Out:
# 'one'

# %%
mylist[1:]
# Out:
# ['two', 'three']

# %%
mylist+my_lists
# Out:
# ['one', 'two', 'three', 'string', 100, 34.7]

# %%
new_list=mylist+my_lists

# %%
mylist[-1]
# Out:
# 'three'

# %%
new_list
# Out:
# ['one', 'two', 'three', 'string', 100, 34.7]

# %%
new_list[0]='1'

# %%
new_list #mutable
# Out:
# ['1', 'two', 'three', 'string', 100, 34.7]

# %%
new_list.append(45)

# %%
new_list
# Out:
# ['1', 'two', 'three', 'string', 100, 34.7, 45]

# %%
new_list.append([5,6,7])

# %%
new_list
# Out:
# ['1', 'two', 'three', 'string', 100, 34.7, 45, [5, 6, 7]]

# %%
#list operations are inplace
new_list.extend([0,6])

# %%
new_list
# Out:
# ['1', 'two', 'three', 'string', 100, 34.7, 45, [5, 6, 7], 0, 6]

# %%
new_list.extend('vanshika')

# %%
new_list
# Out:
# ['1',
#  'two',
#  'three',
#  'string',
#  100,
#  34.7,
#  45,
#  [5, 6, 7],
#  0,
#  6,
#  'v',
#  'a',
#  'n',
#  's',
#  'h',
#  'i',
#  'k',
#  'a']

# %%
new_list.pop()
# Out:
# 'a'

# %%
new_list
# Out:
# ['1',
#  'two',
#  'three',
#  'string',
#  100,
#  34.7,
#  45,
#  [5, 6, 7],
#  0,
#  6,
#  'v',
#  'a',
#  'n',
#  's',
#  'h',
#  'i',
#  'k']

# %%
popped_item=new_list.pop()

# %%
popped_item
# Out:
# 'k'

# %%
new_list.pop(0) #index
# Out:
# '1'

# %%
new_list
# Out:
# ['two',
#  'three',
#  'string',
#  100,
#  34.7,
#  45,
#  [5, 6, 7],
#  0,
#  6,
#  'v',
#  'a',
#  'n',
#  's',
#  'h',
#  'i']

# %%
# default =-1 for pop()
#new_list.pop(80)

# %%
new_list=['a','e','i','o','c','t','w','u']

# %%
num_list=[5,6,63,22]
num_list.sort()

# %%
num_list
# Out:
# [5, 6, 22, 63]

# %%
# sort returns None

# %%
type(num_list.sort())
# Out:
# NoneType

# %%
num_list.reverse()

# %%
num_list
# Out:
# [63, 22, 6, 5]

# %% [markdown]
# ## Dictionary
# - Dictionaries are unordered mappings for storing objects.Previously we saw how lists store objects in an ordered sequence , the key-value pair allows users to quickly grab objects without needing to know an index location
# - dictionaries use curly braces and colons to signify the keys and their associated values .{"key1":"value1","key2":"value2"}
#
# When to use dictionaries and when to use lists ?
# - dictionaries are objects retrieved by key name .
# Unordered and cannot be sorted
# - lists are objects retrieved by location .
# Ordered Sequence can be indexed or sliced.

# %%
my_dict={"key1":"value1","key2":"value2"}
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
my_dict['key1']
# Out:
# 'value1'

# %%
prices_lookup={'apple':2.99,'oranges':1.99,'milk':5.8}
prices_lookup['apple']
# Out:
# 2.99

# %%
# dictionary are flexible for holding different type of values but key must be mutable
d={'k1':123,'k2':[6,7,7],'k3':{'a':'100'}}
d['k3']['a']
# Out:
# '100'

# %%
d={'key1':['a','b','c']}
myitem=d['key1'][2].upper()
myitem
# Out:
# 'C'

# %%
# add new value
d={'k1':100,'k2':200}
d['k3']=600
d
# Out:
# {'k1': 100, 'k2': 200, 'k3': 600}

# %%
d['k1']='230'

# %%
d
# Out:
# {'k1': '230', 'k2': 200, 'k3': 600}

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
d.values()
# Out:
# dict_values(['230', 200, 600])

# %%
d.items()
# Out:
# dict_items([('k1', '230'), ('k2', 200), ('k3', 600)])

# %% [markdown]
# ### Tuples
#  - similar to lists but are immutable
#  - use paranthesis (1,2,4)

# %%
t=(1,2,3)
my_list=[1,3,3]
print(type(t))
print(type(my_list))
# Out:
# <class 'tuple'>
# <class 'list'>

# %%
t=(1,2,3)
t=('5','5',0,'one')

# %%
print(t[0])
print(t[1:3])
# Out:
# 5
# ('5', 0)

# %%
t.count('5')
# Out:
# 2

# %%
t.count(0)
# Out:
# 1

# %%
t.count(-5)
# Out:
# 0

# %%
t.index('5')
# Out:
# 0

# %%
t.index('5',1)
# Out:
# 1

# %%
#t[0]='3'

# %%
# tuples used when we want data integrity

# %% [markdown]
# ## Sets
# - sets are unordered collections of unique elements .Meaning there can only be one representative of the same object.

# %%
myset=set()
myset
# Out:
# set()

# %%
myset.add(1)
myset
# Out:
# {1}

# %%
myset.add(2)

# %%
myset
# Out:
# {1, 2}

# %%
myset.add(2)

# %%
myset
# Out:
# {1, 2}

# %%
set(mylist)
# Out:
# {'E', 'H', 'R', 'T'}

# %% [markdown]
# ### BOOLEANS
#
# booleans are operators that allow you to convey True or False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(False)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %%
1>5 #comparison operators return true and false
# Out:
# False

# %%
1==1
# Out:
# True

# %%
4<8
# Out:
# True

# %%
# None as a placeholder
b=None
print(b)
print(type(b))
# Out:
# None
# <class 'NoneType'>
