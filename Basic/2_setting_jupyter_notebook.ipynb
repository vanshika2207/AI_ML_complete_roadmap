# %%
print("hi")
# Out:
# hi

# %%
import numpy as np

# %%
import pandas as pd

# %%
print("Hello")
# Out:
# Hello

# %%
print('this is the code')
# Out:
# this is the code

# %% [markdown]
# this is the markdown text
#
# ## Heading level 2
# #  Heading level 1
